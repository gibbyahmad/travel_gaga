# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import sqlite3
from pymongo import MongoClient

file_to_load = "Arrivals_NonRes.csv"

# Read Purchasing File and store into Pandas data frame
base_data = pd.read_csv(file_to_load, encoding="UTF-8")
base_data
# Out:
#              COUNTRY CODE   LATITUDE   LONGITUDE  \
# 0        AFGHANISTAN   AF  33.939110   67.709953
# 1        AFGHANISTAN   AF  33.939110   67.709953
# 2        AFGHANISTAN   AF  33.939110   67.709953
# 3        AFGHANISTAN   AF  33.939110   67.709953
# 4        AFGHANISTAN   AF  33.939110   67.709953
# 5        AFGHANISTAN   AF  33.939110   67.709953
# 6        AFGHANISTAN   AF  33.939110   67.709953
# 7        AFGHANISTAN   AF  33.939110   67.709953
# 8            ALBANIA   AL  41.153332   20.168331
# 9            ALBANIA   AL  41.153332   20.168331
# 10           ALBANIA   AL  41.153332   20.168331
# 11           ALBANIA   AL  41.153332   20.168331
# 12           ALBANIA   AL  41.153332   20.168331
# 13           ALBANIA   AL  41.153332   20.168331
# 14           ALBANIA   AL  41.153332   20.168331
# 15           ALBANIA   AL  41.153332   20.168331
# 16           ALGERIA   DZ  28.033886    1.659626
# 17           ALGERIA   DZ  28.033886    1.659626
# ...

# %%
#base_data.replace({'..': np.nan})
base_data.replace({'..': 0})
# Out:
#              COUNTRY CODE   LATITUDE   LONGITUDE  \
# 0        AFGHANISTAN   AF  33.939110   67.709953
# 1        AFGHANISTAN   AF  33.939110   67.709953
# 2        AFGHANISTAN   AF  33.939110   67.709953
# 3        AFGHANISTAN   AF  33.939110   67.709953
# 4        AFGHANISTAN   AF  33.939110   67.709953
# 5        AFGHANISTAN   AF  33.939110   67.709953
# 6        AFGHANISTAN   AF  33.939110   67.709953
# 7        AFGHANISTAN   AF  33.939110   67.709953
# 8            ALBANIA   AL  41.153332   20.168331
# 9            ALBANIA   AL  41.153332   20.168331
# 10           ALBANIA   AL  41.153332   20.168331
# 11           ALBANIA   AL  41.153332   20.168331
# 12           ALBANIA   AL  41.153332   20.168331
# 13           ALBANIA   AL  41.153332   20.168331
# 14           ALBANIA   AL  41.153332   20.168331
# 15           ALBANIA   AL  41.153332   20.168331
# 16           ALGERIA   DZ  28.033886    1.659626
# 17           ALGERIA   DZ  28.033886    1.659626
# ...

# %%
DB_Name = 'Tourism_DB'
engine = create_engine(f'sqlite:///{DB_Name}')

# %%
engine.execute('CREATE TABLE "Tourism" ('
               'Country VARCHAR NOT NULL,'
               'Code VARCHAR,'
               'Latitude FLOAT NOT NULL,'
               'Longitude FLOAT NOT NULL,'
               'Tourism VARCHAR NOT NULL,'
               '`1995` FLOAT NOT NULL,'
               '`1996` FLOAT NOT NULL,'
               '`1997` FLOAT NOT NULL,'
               '`1998` FLOAT NOT NULL,'
               '`1999` FLOAT NOT NULL,'
               '`2000` FLOAT NOT NULL,'
               '`2001` FLOAT NOT NULL,'
               '`2002` FLOAT NOT NULL,'
               '`2003` FLOAT NOT NULL,'
               '`2004` FLOAT NOT NULL,'
               '`2005` FLOAT NOT NULL,'
               '`2006` FLOAT NOT NULL,'
               '`2007` FLOAT NOT NULL,'
               '`2008` FLOAT NOT NULL,'
               '`2009` FLOAT NOT NULL,'
               '`2010` FLOAT NOT NULL,'
               '`2011` FLOAT NOT NULL,'
               '`2012` FLOAT NOT NULL,'
               '`2013` FLOAT NOT NULL,'
               '`2014` FLOAT NOT NULL,'
               '`2015` FLOAT NOT NULL,'
               '`2016` FLOAT NOT NULL,'
               '`2017` FLOAT NOT NULL);')

# %%
base_data.to_sql(name='Tourism', con=engine, if_exists='append', index=False)

# %%
# Connecting to the Database
cnx = sqlite3.connect('Tourism_DB')

# Converting a Table in the Database into a Pandas DataFrame
df = pd.read_sql_query("SELECT * FROM Tourism", cnx)

# %%
df
# Out:
#              Country Code   Latitude   Longitude  \
# 0        AFGHANISTAN   AF  33.939110   67.709953
# 1        AFGHANISTAN   AF  33.939110   67.709953
# 2        AFGHANISTAN   AF  33.939110   67.709953
# 3        AFGHANISTAN   AF  33.939110   67.709953
# 4        AFGHANISTAN   AF  33.939110   67.709953
# 5        AFGHANISTAN   AF  33.939110   67.709953
# 6        AFGHANISTAN   AF  33.939110   67.709953
# 7        AFGHANISTAN   AF  33.939110   67.709953
# 8            ALBANIA   AL  41.153332   20.168331
# 9            ALBANIA   AL  41.153332   20.168331
# 10           ALBANIA   AL  41.153332   20.168331
# 11           ALBANIA   AL  41.153332   20.168331
# 12           ALBANIA   AL  41.153332   20.168331
# 13           ALBANIA   AL  41.153332   20.168331
# 14           ALBANIA   AL  41.153332   20.168331
# 15           ALBANIA   AL  41.153332   20.168331
# 16           ALGERIA   DZ  28.033886    1.659626
# 17           ALGERIA   DZ  28.033886    1.659626
# ...
