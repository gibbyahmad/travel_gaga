# %%
# Dependencies
import pandas as pd
import numpy as np
import json

# %%
# Name of the CSV file
file = 'Resources/arrivals_tourist.csv'

# %%
# The correct encoding must be used to read the CSV in pandas
df = pd.read_csv(file, encoding="ISO-8859-1")
# df = pd.read_csv('Resources/temp.csv')

# %%
# Preview of the DataFrame
# Note that FIELD8 is likely a meaningless column
df
# Out:
#                                        COUNTRY CODE   LATITUDE  LONGTITUDE  \
# 0                                  AFGHANISTAN   AF  33.939110   67.709953
# 1                                      ALBANIA   AL  41.153332   20.168331
# 2                                      ALGERIA   DZ  28.033886    1.659626
# 3                               AMERICAN SAMOA   AS -14.270972 -170.132217
# 4                                      ANDORRA   AD  42.546245    1.601554
# 5                                       ANGOLA   AO -11.202692   17.873887
# 6                                     ANGUILLA   AI  18.220554  -63.068615
# 7                          ANTIGUA AND BARBUDA   AG  17.060816  -61.796428
# 8                                    ARGENTINA   AR -38.416097  -63.616672
# 9                                      ARMENIA   AM  40.069099   45.038189
# 10                                       ARUBA   AW  12.521110  -69.968338
# ...

# %%
datafile=pd.read_csv(file, encoding="ISO-8859-1")
df.to_json("arrival_tourist.json")

# %%
#json to dictionary USING arrival_tourist.json
jsonfilepath = "arrival_tourist.json"

arrival_tour = {}
try:
    with open(jsonfilepath) as data_file:
        arrival_tour = json.load(data_file)
except IOError as e:
    print (e)
    print ("IOError: Unable to open file")
    exit(1)

# %%
type(arrival_tour)
# Out:
# dict

# %%
arrival_tour.keys()
# Out:
# dict_keys(['COUNTRY', 'CODE', 'LATITUDE', 'LONGTITUDE', 'IN Arrivals - Thousands', 'IN Tourism expenditure in the country - US$ Mn', 'IN Travel - US$ Mn', 'IN Passenger transport - US$ Mn', 'OUT Departures - Thousands', 'OUT Tourism expenditure in other countries - US$ Mn', 'OUT Travel - US$ Mn', 'OUT Passenger transport - US$ Mn'])
